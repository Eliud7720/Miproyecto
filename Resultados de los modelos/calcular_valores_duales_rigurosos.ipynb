# %%
import pandas as pd

# %%
inhibidores = pd.read_csv("../Resultados de la aplicacion/inhibidores_duales_rigurosos.csv")

# %%
inhibidores
# Out:
#     Unnamed: 0 Molecule ChEMBL ID  Standard Value_EGFR  Standard Value_MAPK1  \
# 0            0      CHEMBL2178352                  0.4               10000.0
# 1           13       CHEMBL388978                 78.0                 370.0
# 2           24       CHEMBL569880                 11.0               10000.0
# 3           25       CHEMBL571040                 24.0               10000.0
# 4           44         CHEMBL1336              50000.0                 109.5
# 5           54      CHEMBL4798527                651.0               10000.0
# 6           62      CHEMBL1090360                610.0                1000.0
# 7           67      CHEMBL1684800                101.4               11380.0
# 8           80      CHEMBL4062877                  5.3                 574.7
# 9           82      CHEMBL4105329                  3.1                 960.2
# 10          83      CHEMBL4067871                  4.2                1000.0
# ...

# %%
inhibidores[""]
